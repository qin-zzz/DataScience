# %% [markdown]
# # Memory optimization with dtype conversion
#
# **0.Check memory usage**
#
# *df.memory_usage(memory_usage='deep')
# sys.getsizeof*
#
# **1.Numeric**
#
# *df.to_numeric()*
#
# **2.Object**
#
# *df.astype('category')*
#
# **3.Datetime**
#
# *pd.to_datetime()*
#
# **4.Automatic conversion**
#
# reference: https://www.dataquest.io/blog/pandas-big-data/
# dataset: https://data.world/dataquest/mlb-game-logs/workspace/data-dictionary

# %%
import numpy as np
import pandas as pd
import platform

print('Python', platform.python_version())
print('Numpy', np.__version__)
print('Pandas', pd.__version__)

pd.set_option('display.max_columns', 500)
# Out:
# Python 3.7.4
# Numpy 1.20.1
# Pandas 1.2.2

# %%
gl = pd.read_csv('./dataset/game_logs.csv')
gl
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (12,13,14,15,19,20,81,83,85,87,93,94,95,96,97,98,99,100,105,106,108,109,111,112,114,115,117,118,120,121,123,124,126,127,129,130,132,133,135,136,138,139,141,142,144,145,147,148,150,151,153,154,156,157,160) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             date  number_of_game day_of_week v_name v_league  v_game_number  \
# 0       18710504               0         Thu    CL1       na              1
# 1       18710505               0         Fri    BS1       na              1
# 2       18710506               0         Sat    CL1       na              2
# 3       18710508               0         Mon    CL1       na              3
# 4       18710509               0         Tue    BS1       na              2
# ...

# %% [markdown]
# ## Understanding pandas dtype and memory usage

# %%
# By default, pandas approximates of the memory usage of the dataframe to save time.
gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171907 entries, 0 to 171906
# Columns: 161 entries, date to acquisition_info
# dtypes: float64(77), int64(6), object(78)
# memory usage: 211.2+ MB

# %%
# set the memory_usage parameter to 'deep' to get an accurate number.
gl.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171907 entries, 0 to 171906
# Columns: 161 entries, date to acquisition_info
# dtypes: float64(77), int64(6), object(78)
# memory usage: 859.4 MB

# %% [markdown]
# *Object columns are used for strings or where a column contains mixed data types.*

# %%
for dtype in ['float','int','object']:
    selected_dtype = gl.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 1.29 MB
# Average memory usage for int columns: 1.12 MB
# Average memory usage for object columns: 9.50 MB

# %% [markdown]
# *Immediately we can see that most of our memory is used by our 78 object columns.*

# %%
# define a function calculating memory usage for the next steps
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: # we assume if not a df it's a series
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # convert bytes to megabytes
    return "{:03.2f} MB".format(usage_mb)

# %% [markdown]
# ## Understanding subtype

# %%
int_types = ["uint8", "int8", "int16"]
for it in int_types:
    print(np.iinfo(it))
# Out:
# Machine parameters for uint8
# ---------------------------------------------------------------
# min = 0
# max = 255
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------

# %% [markdown]
# *An int8 value uses 1 byte (or 8 bits) to store a value, and can represent 256 values (2^8) in binary. This means that we can use this subtype to represent values ranging from -128 to 127 (including 0).*
#
# **Unsigned integers allow us to be more efficient with our storage of columns that only contain positive values.**

# %% [markdown]
# ## Optimizing numeric columns with subtypes

# %%
gl_int = gl.select_dtypes(include=['int'])
converted_int = gl_int.apply(pd.to_numeric,downcast='unsigned')

# %%
gl_int
# Out:
#             date  number_of_game  v_game_number  h_game_number  v_score  \
# 0       18710504               0              1              1        0
# 1       18710505               0              1              1       20
# 2       18710506               0              2              1       12
# 3       18710508               0              3              1       12
# 4       18710509               0              2              1        9
# ...          ...             ...            ...            ...      ...
# 171902  20161002               0            162            162        6
# 171903  20161002               0            162            162        2
# 171904  20161002               0            162            162        1
# 171905  20161002               0            162            162        4
# 171906  20161002               0            161            162        7
#
#         h_score
# 0             2
# 1            18
# 2             4
# 3            14
# ...

# %%
converted_int
# Out:
#             date  number_of_game  v_game_number  h_game_number  v_score  \
# 0       18710504               0              1              1        0
# 1       18710505               0              1              1       20
# 2       18710506               0              2              1       12
# 3       18710508               0              3              1       12
# 4       18710509               0              2              1        9
# ...          ...             ...            ...            ...      ...
# 171902  20161002               0            162            162        6
# 171903  20161002               0            162            162        2
# 171904  20161002               0            162            162        1
# 171905  20161002               0            162            162        4
# 171906  20161002               0            161            162        7
#
#         h_score
# 0             2
# 1            18
# 2             4
# 3            14
# ...

# %%
print(mem_usage(gl_int))
print(mem_usage(converted_int))
# Out:
# 7.87 MB
# 1.48 MB

# %%
compare_ints = pd.concat([gl_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns = ['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
#         before  after
# uint8      NaN    5.0
# uint32     NaN    1.0
# int64      6.0    NaN

# %%
gl_float = gl.select_dtypes(include=['float'])
converted_float = gl_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(gl_float))
print(mem_usage(converted_float))

compare_floats = pd.concat([gl_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns = ['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 100.99 MB
# 50.49 MB
#          before  after
# float32     NaN   77.0
# float64    77.0    NaN

# %% [markdown]
# A drop from 7.9 to 1.5 megabytes in memory usage, which is a more than 80% reduction.
#
# All our float columns were converted from float64 to float32, giving us a 50% reduction in memory usage.

# %% [markdown]
# ## Optimizing object types using categoricals

# %%
from sys import getsizeof

s1 = 'working out'
s2 = 'memory usage for'
s3 = 'strings in python is fun!'
s4 = 'strings in python is fun!'

for s in [s1, s2, s3, s4]:
    print(getsizeof(s))
# Out:
# 60
# 65
# 74
# 74

# %%
obj_series = pd.Series(['working out',
                          'memory usage for',
                          'strings in python is fun!',
                          'strings in python is fun!'])
obj_series.apply(getsizeof)
# Out:
# 0    60
# 1    65
# 2    74
# 3    74
# dtype: int64

# %% [markdown]
# *The size of strings when stored in a pandas series are identical to their usage as separate strings in Python.*

# %%
gl_obj = gl.select_dtypes(include=['object']).copy()
gl_obj.describe()
# Out:
#        day_of_week  v_name v_league  h_name h_league day_night  \
# count       171907  171907   171907  171907   171907    140150
# unique           7     148        7     148        7         2
# top            Sat     CHN       NL     CHN       NL         D
# freq         28891    8870    88866    9024    88867     82724
#
#                    completion forefeit protest park_id v_line_score  \
# count                     116      145     180  171907       147271
# unique                    116        3       5     245        36367
# top     19860724,CIN08,3,2,32        H       V   STL07    000000000
# freq                        1       69      90    7022        10102
#
#        h_line_score hp_umpire_id hp_umpire_name 1b_umpire_id 1b_umpire_name  \
# count        147271       171888         171891       147040         171891
# unique        37859         1149           1146          678            678
# top       000000000     klemb901      Bill Klem     connt901         (none)
# ...

# %% [markdown]
# *A quick glance reveals many columns where there are few unique values relative to the overall ~172,000 games in our data set.*

# %%
converted_obj = pd.DataFrame()

for col in gl_obj.columns:
    num_unique_values = len(gl_obj[col].unique())
    num_total_values = len(gl_obj[col])
    if num_unique_values / num_total_values < 0.5:
        converted_obj.loc[:,col] = gl_obj[col].astype('category')
    else:
        converted_obj.loc[:,col] = gl_obj[col]
        
print(mem_usage(gl_obj))
print(mem_usage(converted_obj))

compare_obj = pd.concat([gl_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns = ['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 750.57 MB
# 49.89 MB
#           before  after
# object      78.0    NaN
# category     NaN    2.0
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
# ...          ...    ...
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
#
# [78 rows x 2 columns]

# %%
print(mem_usage(gl.day_of_week))
print(mem_usage(converted_obj.day_of_week))
# Out:
# 9.84 MB
# 0.16 MB

# %% [markdown]
# ## Why?

# %% [markdown]
# each unique value has been assigned an integer, and that the underlying datatype for the column is now int8. This column doesn’t have any missing values, but if it did, the category subtype handles missing values by setting them to -1.

# %%
converted_obj.day_of_week.head().cat.codes
# Out:
# 0    4
# 1    0
# 2    2
# 3    1
# 4    5
# dtype: int8

# %% [markdown]
# ## Optimizing datetime types

# %%
date = gl.date
print(mem_usage(date))
date.head()
# Out:
# 1.31 MB
# 0    18710504
# 1    18710505
# 2    18710506
# 3    18710508
# 4    18710509
# Name: date, dtype: int64

# %%
optimized_date = pd.to_datetime(date,format='%Y%m%d')
print(mem_usage(optimized_date))
optimized_date.head()
# Out:
# 1.31 MB
# 0   1871-05-04
# 1   1871-05-05
# 2   1871-05-06
# 3   1871-05-08
# 4   1871-05-09
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# *converting it to datetime might not actually cost less memory usage, as the datetime type is a 64 bit type. There’s value in converting it to datetime anyway since it will allow us to more easily do time series analysis.*

# %% [markdown]
# ## Convert dtypes automatically

# %%
gl = pd.read_csv('./dataset/game_logs.csv')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (12,13,14,15,19,20,81,83,85,87,93,94,95,96,97,98,99,100,105,106,108,109,111,112,114,115,117,118,120,121,123,124,126,127,129,130,132,133,135,136,138,139,141,142,144,145,147,148,150,151,153,154,156,157,160) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gl.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171907 entries, 0 to 171906
# Columns: 161 entries, date to acquisition_info
# dtypes: float64(77), int64(6), object(78)
# memory usage: 859.4 MB

# %%
coverted_gl = gl.convert_dtypes()

# %%
coverted_gl.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171907 entries, 0 to 171906
# Columns: 161 entries, date to acquisition_info
# dtypes: Int64(83), object(1), string(77)
# memory usage: 894.2 MB

# %% [markdown]
# *As we can see, it might not be good to use automatic ways to convert dtypes for memory optimization.*
# *A suggesting way is to store the final types of every column in a dictionary with keys for column names and use the dictionary, along with a few parameters for the date to read in the data with the correct types.*
